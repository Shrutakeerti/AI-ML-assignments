# %% [markdown]
# <a href="https://colab.research.google.com/github/Shrutakeerti/AI-ML-assignments/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y=[2,4,6,8,10]

plt.plot(x, y, label='Line 1')
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Line Plot")
plt.legend('vice')
plt.show()

# %%
import matplotlib.pyplot as plt
x=[1,2,3,4,5]
y1=[2,4,6,8,10]
y2=[3,6,9,12,15]

plt.plot(x, y1, label='Line 1', color='b',linestyle=':',marker='o')
plt.plot(x, y2, label='Line 2', color='r',linestyle='--',marker='s')
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Line Plot")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
x=[1,3,4,7,10,14,17,19,10,7,5]
plt.hist(x,bins=5,edgecolor='black')
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Histogram")
plt.show()

# %%
import pandas as pd
df=pd.read_csv('/content/data.txt')
x=[2,4,6,8,10]
y=[3,6,9,12,15]
line=df.iloc[0,0]
values=line.split()
x.append(float(values[0]))
y.append(float(values[1]))
plt.scatter(x, y, color='red',edgecolor='blue')
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Scatter Plot")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
labels=['A','B','C','D']
values=[10,20,30,40]
color=['blue','green','black','red']
plt.pie(values,labels=labels,colors=color,autopct='%1.1f%%')
plt.title("Pie Chart")
plt.show()

# %%
import numpy as np
x=np.linspace(0,2*np.pi,100)
y=np.sin(x)
plt.plot(x,y)
plt.xlabel("X Axis")
plt.ylabel("Y Axis")
plt.title("Sine Wave")
plt.show()

# %%
import numpy as np
x=np.linspace(-10,10,400)
y=x**2
plt.plot(x,y,label='exponential')

plt.xlabel('x axis')
plt.ylabel('y axis')
plt.legend()
plt.show()

# %%
x=np.linspace(-10,100,700)
y=np.exp(x)
plt.plot(x,y,label='y expo x')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.title('plot')
plt.legend()
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
# Create a directed graph
G = nx.DiGraph()
# Add nodes and edges for a simple binary tree
edges = [
('Root', 'Left Child'),
('Root', 'Right Child'),
('Left Child', 'Left Grandchild 1'),
('Left Child', 'Right Grandchild 1'),
('Right Child', 'Left Grandchild 2'),
('Right Child', 'Right Grandchild 2')
]
# Add edges to the graph
G.add_edges_from(edges)
# Draw the graph
pos = nx.spring_layout(G)
nx.draw(G, pos, with_labels=True, node_size=3000, node_color='skyblue', font_size=10,
font_weight='bold', edge_color='gray')
# Add labels
labels = {node: node for node in G.nodes()}
nx.draw_networkx_labels(G, pos, labels)
# Show the plot
plt.title("Simple Binary Tree")
plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
# Create a directed graph
G = nx.DiGraph()
# Add nodes and edges
edges = [
('A', 'B'),
('A', 'C'),
('B', 'D'),
('C', 'D'),
('D', 'E'),
('E', 'F'),
('F', 'C')
]
# Add edges to the graph
G.add_edges_from(edges)
# Draw the graph
pos = nx.spring_layout(G) # Positions nodes using the Fruchterman-Reingold force-directed
nx.draw(G, pos, with_labels=True, node_size=3000, node_color='lightblue', font_size=12,
font_weight='bold', edge_color='gray', arrows=True)
# Add labels
labels = {node: node for node in G.nodes()}
nx.draw_networkx_labels(G, pos, labels)
# Show the plot
plt.title("Directed Graph")
plt.show()
